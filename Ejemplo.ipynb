# %% [markdown]
# <a href="https://colab.research.google.com/github/grbarcenas/grb/blob/main/Ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab as pl
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

pl.plot(X, C)
pl.plot(X, S)

pl.show()

# %%
import pandas as pd
f = [1,1,6,-1,-3,-3,-9,6,4,6,3,4,1,-1,-2,2]
serie = pd.Series(data=f)
fechas=pd.date_range(start='2022-01-01',freq='D',periods=len(f))
serie.index=fechas
print(serie.describe())
print(serie.index[0]) # Acceso al primer elemento
print(serie['2022-01-03']) #Acceso por índice
print(serie.index[0:18]) # Acceso a un rango
serie['2022-01-17']=0
serie.describe()
# Out:
# count    16.000000
# mean      0.937500
# std       4.057401
# min      -9.000000
# 25%      -1.250000
# 50%       1.000000
# 75%       4.000000
# max       6.000000
# dtype: float64
# 2022-01-01 00:00:00
# 6
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16'],
#               dtype='datetime64[ns]', freq='D')
# count    17.000000
# mean      0.882353
# std       3.935136
# min      -9.000000
# 25%      -1.000000
# 50%       1.000000
# 75%       4.000000
# max       6.000000
# dtype: float64

# %%
df2 = pd.read_excel('df.xlsx')
df2.index=df2['Fecha']
df2
#print(df2.describe())
# Out:
#                 Fecha  Cuenta  Caja  Festivo  DiaSem  DiaMes
# Fecha
# 2009-01-01 2009-01-01  Banco1   428        1       4       1
# 2009-01-02 2009-01-02  Banco2  3832        0       5       2
# 2009-01-03 2009-01-03  Banco3   -47        1       6       3
# 2009-01-04 2009-01-04  Banco2     0        1       7       4
# 2009-01-05 2009-01-05  Banco2 -1151        0       1       5
# 2009-01-06 2009-01-06  Banco2  -820        1       2       6
# 2009-01-07 2009-01-07  Banco3   906        0       3       7
# 2009-01-08 2009-01-08  Banco1  1898        0       4       8
# 2009-01-09 2009-01-09  Banco1  1771        0       5       9
# 2009-01-10 2009-01-10  Banco3     0        1       6      10
# 2009-01-11 2009-01-11  Banco1     0        1       7      11
# 2009-01-12 2009-01-12  Banco1     0        0       1      12
# 2009-01-13 2009-01-13  Banco3   960        0       2      13
# 2009-01-14 2009-01-14  Banco3   190        0       3      14
# ...

# %%
midiccionario = {'Nombre':['María', 'Luis', 'Carmen', 'Antonio'], 
                 'Edad':[18, 22, 20, 21],
                 'Grado':['Economía', 'Medicina', 'Arquitectura', 'Economía'],
                 'Correo':['maria@gmail.com', 'luis@yahoo.es', 'carmen@gmail.com', 'antonio@gmail.com']}
import pandas as pd
df = df = pd.DataFrame(midiccionario)
df
# Out:
#     Nombre  Edad         Grado             Correo
# 0    María    18      Economía    maria@gmail.com
# 1     Luis    22      Medicina      luis@yahoo.es
# 2   Carmen    20  Arquitectura   carmen@gmail.com
# 3  Antonio    21      Economía  antonio@gmail.com

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Cargar el conjunto de datos de los planetas de ejemplo
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)
g.fig.savefig("test.png")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(color_codes=True)
tips = sns.load_dataset("tips")
print(tips)
sns.regplot(x="total_bill", y="tip", data=tips)
plt.savefig('filename1.png')
sns.lmplot(x="total_bill", y="tip", data=tips)
plt.savefig('filename2.png')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({"Day 1": [7,1,5,6,3,10,5,8],
                    "Day 2" : [1,2,8,4,3,9,5,2]})

sns.lineplot(data = df)
plt.savefig('filename.png', orientation = 'horizontal')

# %%
import pandas as pd
df = pd.read_csv('/content/country_wise_latest.csv')
import seaborn as sns
sns.lineplot(data = df)
sns.lmplot(x="Confirmed", y="Recovered", hue="WHO Region",data=df)
